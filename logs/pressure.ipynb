# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.dates as mdates
import datetime
import numpy as np

# %%
df = pd.read_csv('monitoring/monitoring.log.2024-03-31',delimiter=' - ',skiprows=2235)
df.head()
# Out:
# C:\Users\Scienta Omicron\AppData\Local\Temp\ipykernel_425108\288661167.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv('monitoring/monitoring.log.2024-03-31',delimiter=' - ',skiprows=2235)
#    2024-03-31 17:20:38,969  monitoring  199.0  11.0  12.0  34.0   292.4  \
# 0  2024-03-31 17:20:44,005  monitoring  199.0  11.0  12.0  34.0  292.41
# 1  2024-03-31 17:20:49,025  monitoring  199.0  11.0  12.0  34.0  292.41
# 2  2024-03-31 17:20:53,897  monitoring  199.0  11.0  12.0  34.0  292.41
# 3  2024-03-31 17:20:58,938  monitoring  199.0  11.0  12.0  34.0  292.41
# 4  2024-03-31 17:21:03,982  monitoring  199.0  11.0  12.0  34.0  292.41
#
#    292.31
# 0  292.31
# 1  292.31
# 2  292.31
# 3  292.31
# 4  292.31

# %%
time = df['2024-03-31 17:20:38,969']
time1 = pd.to_datetime(time,format="%Y-%m-%d %H:%M:%S,%f")
T = df["292.31"]

# %%
plt.plot(time1,df["199.0"])

ax = plt.gca()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))

plt.show()

# %%
plt.plot(time1,T)

ax = plt.gca()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))

plt.show()

# %%
df2 = pd.read_csv('monitoring/monitoring.log.2024-04-01',delimiter=' - ',skiprows=1)
df2.head()
# Out:
# C:\Users\Scienta Omicron\AppData\Local\Temp\ipykernel_425108\3318100190.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df2 = pd.read_csv('monitoring/monitoring.log.2024-04-01',delimiter=' - ',skiprows=1)
#    2024-04-01 00:00:04,027  monitoring  196.0  22.0  25.0  24.0  292.41  \
# 0  2024-04-01 00:00:09,043  monitoring  196.0  22.0  25.0  24.0  292.41
# 1  2024-04-01 00:00:13,935  monitoring  196.0  22.0  25.0  24.0  292.41
# 2  2024-04-01 00:00:18,976  monitoring  196.0  22.0  25.0  24.0  292.41
# 3  2024-04-01 00:00:24,017  monitoring  196.0  22.0  25.0  24.0  292.41
# 4  2024-04-01 00:00:29,049  monitoring  196.0  22.0  25.0  24.0  292.41
#
#    292.63
# 0  292.63
# 1  292.63
# 2  292.63
# 3  292.63
# 4  292.63

# %%
df3 = pd.read_csv('monitoring/monitoring.log.2024-04-02',delimiter=' - ',skiprows=1)
df3.head()
# Out:
# C:\Users\Scienta Omicron\AppData\Local\Temp\ipykernel_425108\3740922174.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df3 = pd.read_csv('monitoring/monitoring.log.2024-04-02',delimiter=' - ',skiprows=1)
#    2024-04-02 00:00:14,203  monitoring  195.0  21.0  23.0  22.0  292.36  292.6
# 0  2024-04-02 00:00:44,231  monitoring  195.0  21.0  23.0  22.0  292.36  292.6
# 1  2024-04-02 00:01:14,254  monitoring  195.0  21.0  23.0  22.0  292.36  292.6
# 2  2024-04-02 00:01:44,250  monitoring  195.0  21.0  23.0  22.0  292.36  292.6
# 3  2024-04-02 00:02:14,281  monitoring  195.0  21.0  23.0  22.0  292.36  292.6
# 4  2024-04-02 00:02:44,142  monitoring  195.0  21.0  23.0  22.0  292.36  292.6

# %%
time3 = df3['2024-04-02 00:00:14,203']
time3 = pd.to_datetime(time3,format="%Y-%m-%d %H:%M:%S,%f")
T3 = df3["292.6"]
p3 = df3["195.0"]

# %%
time2 = df2['2024-04-01 00:00:04,027']
time2 = pd.to_datetime(time2,format="%Y-%m-%d %H:%M:%S,%f")
T2 = df2["292.63"]

# %%
plt.plot(time2,df2["196.0"])

ax = plt.gca()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))

plt.show()

# %%
plt.plot(time2,T2)

ax = plt.gca()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))

plt.show()

# %%
plt.plot(time2,df2["196.0"])
plt.plot(time1,df["199.0"])
ax = plt.gca()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))

plt.show()

# %%
plt.plot(time2,df2["196.0"])
plt.plot(time1,df["199.0"])
plt.plot(time3,p3)
ax = plt.gca()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
ax2 = ax.twinx()
ax2.plot(time2,T2)
ax2.plot(time1,T)
ax2.plot(time3,T3)
plt.show()

# %%
plt.plot(time2,T2)
plt.plot(time1,T)
plt.plot(time3,T3)
ax = plt.gca()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))

plt.show()

# %%
def smooth(y, box_pts):
    box = np.ones(box_pts)/box_pts
    y_smooth = np.convolve(y, box, mode='same')
    return y_smooth

# %%
plt.plot(time2,smooth(df2["196.0"],20))
plt.plot(time1,smooth(df["199.0"],20))
ax = plt.gca()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
plt.ylim([193,200])
plt.show()

# %%
#plt.plot(T,df["199.0"])
plt.plot(T2,df2["196.0"])
plt.plot(T3,p3)
plt.show()

# %%
df = pd.read_csv('monitoring/monitoring.log',delimiter=' - ',skiprows=2235)
df.head()
# Out:
# C:\Users\Scienta Omicron\AppData\Local\Temp\ipykernel_425108\868099908.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv('monitoring/monitoring.log',delimiter=' - ',skiprows=2235)
#    2024-04-03 03:06:13,989  monitoring  196.0  21.0  23.0  22.0  292.14  \
# 0  2024-04-03 03:06:19,042  monitoring  196.0  21.0  23.0  22.0  292.14
# 1  2024-04-03 03:06:23,950  monitoring  196.0  21.0  23.0  22.0  292.14
# 2  2024-04-03 03:06:29,009  monitoring  196.0  21.0  23.0  22.0  292.14
# 3  2024-04-03 03:06:34,045  monitoring  196.0  21.0  23.0  22.0  292.14
# 4  2024-04-03 03:06:38,951  monitoring  196.0  21.0  23.0  22.0  292.14
#
#    292.41
# 0  292.41
# 1  292.41
# 2  292.41
# 3  292.41
# 4  292.41

# %%
time = df['2024-04-03 03:06:13,989']
time = pd.to_datetime(time,format="%Y-%m-%d %H:%M:%S,%f")
T = df["292.41"]
P=df["196.0"]

# %%
plt.plot(time,P)
ax = plt.gca()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
ax2 = ax.twinx()
ax2.plot(time,T)


plt.show()
